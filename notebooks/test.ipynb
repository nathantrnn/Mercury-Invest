# %%
import os
import pandas as pd

# Specify the paths to both bronze layer directories
bronze_layer_dirs = ['../data-lake/bronze/fred/']

# Iterate through each directory
for bronze_layer_dir in bronze_layer_dirs:
    print(f"Processing directory: {bronze_layer_dir}\n")

    # Ensure the directory exists
    if not os.path.exists(bronze_layer_dir):
        print(f"Directory {bronze_layer_dir} does not exist. Skipping...\n")
        continue

    # Iterate through all files in the directory
    for file_name in os.listdir(bronze_layer_dir):
        if file_name.endswith('.csv'):
            try:
                file_path = os.path.join(bronze_layer_dir, file_name)

                # Read the CSV file
                data = pd.read_csv(file_path)

                # Display file name, column names, data types, and sample data
                print(f"File: {file_name}")
                print("Column Names and Data Types:")
                print(data.dtypes)
                print("\nSample Data:")
                print(data.head(50))
                print("\n" + "=" * 50 + "\n")

            except Exception as e:
                # Handle errors that occur during file reading
                print(f"Error reading file {file_name}: {e}")

    print("=" * 200 + "\n")
# Out:
# Processing directory: ../data-lake/bronze/fred/
#
# File: raw_FEDFUNDS.csv
# Column Names and Data Types:
# Date      object
# Value    float64
# dtype: object
#
# Sample Data:
#           Date  Value
# 0   1954-07-01   0.80
# 1   1954-08-01   1.22
# 2   1954-09-01   1.07
# 3   1954-10-01   0.85
# 4   1954-11-01   0.83
# 5   1954-12-01   1.28
# 6   1955-01-01   1.39
# 7   1955-02-01   1.29
# 8   1955-03-01   1.35
# 9   1955-04-01   1.43
# 10  1955-05-01   1.43
# 11  1955-06-01   1.64
# 12  1955-07-01   1.68
# 13  1955-08-01   1.96
# 14  1955-09-01   2.18
# 15  1955-10-01   2.24
# 16  1955-11-01   2.35
# 17  1955-12-01   2.48
# 18  1956-01-01   2.45
# 19  1956-02-01   2.50
# 20  1956-03-01   2.50
# 21  1956-04-01   2.62
# 22  1956-05-01   2.75
# 23  1956-06-01   2.71
# 24  1956-07-01   2.75
# 25  1956-08-01   2.73
# 26  1956-09-01   2.95
# 27  1956-10-01   2.96
# 28  1956-11-01   2.88
# 29  1956-12-01   2.94
# 30  1957-01-01   2.84
# 31  1957-02-01   3.00
# 32  1957-03-01   2.96
# 33  1957-04-01   3.00
# 34  1957-05-01   3.00
# 35  1957-06-01   3.00
# 36  1957-07-01   2.99
# 37  1957-08-01   3.24
# 38  1957-09-01   3.47
# 39  1957-10-01   3.50
# 40  1957-11-01   3.28
# 41  1957-12-01   2.98
# 42  1958-01-01   2.72
# 43  1958-02-01   1.67
# 44  1958-03-01   1.20
# 45  1958-04-01   1.26
# 46  1958-05-01   0.63
# 47  1958-06-01   0.93
# 48  1958-07-01   0.68
# 49  1958-08-01   1.53
#
# ==================================================
#
# File: raw_UNRATE.csv
# Column Names and Data Types:
# Date      object
# Value    float64
# dtype: object
#
# Sample Data:
#           Date  Value
# 0   1948-01-01    3.4
# 1   1948-02-01    3.8
# 2   1948-03-01    4.0
# 3   1948-04-01    3.9
# 30  1953-07-01  391.171
# 31  1953-10-01  385.970
# 32  1954-01-01  385.345
# 33  1954-04-01  386.121
# 34  1954-07-01  390.996
# 35  1954-10-01  399.734
# 36  1955-01-01  413.073
# 37  1955-04-01  421.532
# 38  1955-07-01  430.221
# 39  1955-10-01  437.092
# 40  1956-01-01  439.746
# 41  1956-04-01  446.010
# 42  1956-07-01  451.191
# 43  1956-10-01  460.463
# 44  1957-01-01  469.779
# 45  1957-04-01  472.025
# 46  1957-07-01  479.490
# 47  1957-10-01  474.864
# 48  1958-01-01  467.540
# 49  1958-04-01  471.978
#
# ==================================================
#
# ========================================================================================================================================================================================================

# %%
import os
import pandas as pd

# Define the directory containing the CSV files
csv_directory = "../data-lake/bronze/kaggle/"

# List all CSV files in the directory
csv_files = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]

# Loop through each CSV file and print sample data
for csv_file in csv_files:
    file_path = os.path.join(csv_directory, csv_file)
    print(f"Sample data from file: {csv_file}")
    sample_data = pd.read_csv(file_path).head()  # Read the first 5 rows of the file
    print(sample_data)
    print("\n")
# Out:
# Sample data from file: 20241218_sp500_companies.csv
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 2      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 3      NMS   AMZN       Amazon.com, Inc.       Amazon.com, Inc.
# 4      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        253.48
# 1              Technology       Software - Infrastructure        454.46
# 2              Technology                  Semiconductors        130.39
# 3       Consumer Cyclical                 Internet Retail        231.15
# 4  Communication Services  Internet Content & Information        197.12
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3831552802816  1.346610e+11          0.061      Cupertino    CA
# 1  3378855542784  1.365520e+11          0.160        Redmond    WA
# 2  3193251037184  6.118400e+10          1.224    Santa Clara    CA
# 3  2430542282752  1.115830e+11          0.110        Seattle    WA
# 4  2402932228096  1.234700e+11          0.151  Mountain View    CA
#
#          Country  Fulltimeemployees  \
# 0  United States           164000.0
# 1  United States           228000.0
# 2  United States            29600.0
# 3  United States          1551000.0
# 4  United States           181269.0
#
#                                  Longbusinesssummary    Weight
# 0  Apple Inc. designs, manufactures, and markets ...  0.067521
# 1  Microsoft Corporation develops and supports so...  0.059544
# 2  NVIDIA Corporation provides graphics and compu...  0.056273
# 3  Amazon.com, Inc. engages in the retail sale of...  0.042832
# 4  Alphabet Inc. offers various products and plat...  0.042346
#
#
# Sample data from file: 20241218_sp500_stocks.csv
#          Date Symbol  Adj Close      Close       High        Low       Open  \
# 0  2010-01-04    MMM  43.783867  69.414719  69.774246  69.122070  69.473244
# 1  2010-01-05    MMM  43.509632  68.979935  69.590302  68.311035  69.230766
# 2  2010-01-06    MMM  44.126652  69.958191  70.735786  69.824417  70.133781
# 3  2010-01-07    MMM  44.158318  70.008362  70.033447  68.662209  69.665550
# 4  2010-01-08    MMM  44.469490  70.501671  70.501671  69.648827  69.974915
#
#       Volume
# 0  3640265.0
# 1  3405012.0
# 2  6301126.0
# 3  5346240.0
# 4  4073337.0
#
#
# Sample data from file: 20241218_sp500_index.csv
#          Date   S&P500
# 0  2014-12-17  2012.89
# 1  2014-12-18  2061.23
# 2  2014-12-19  2070.65
# 3  2014-12-22  2078.54
# 4  2014-12-23  2082.17
